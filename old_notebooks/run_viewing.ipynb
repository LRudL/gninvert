# %%
# %load_ext autoreload
# %autoreload 2
import os
import torch as t
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gninvert.rule_discovery import *
from gninvert.gns import RecoveredGN
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
(sim1r, sim1m) = view_run_results("runs/copied/sim1")
# Out:
# GNN_full()

# %%
find_rules_for_model(sim1m, save_location = "runs/copied/sim1/sr")
# Out:
# /home/lrudl/.pyenv/versions/3.9.10/lib/python3.9/site-packages/pysr/sr.py:567: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# ┌ Warning: Replacing module `Parsers`
# └ @ Base loading.jl:1036
# ┌ Warning: Replacing module `MacroTools`
# └ @ Base loading.jl:1036
# /home/lrudl/.pyenv/versions/3.9.10/lib/python3.9/site-packages/pysr/sr.py:567: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# RecoveredGN()

# %%
(sim2r, sim2m) = view_run_results("runs/copied/sim2")
# Out:
# GNN_full()

# %%
from gninvert.gns import *

# %%
sr = find_rules_for_model(sim2m, save_location="runs/copied/sim2/sr")
# Out:
# /home/lrudl/.pyenv/versions/3.9.10/lib/python3.9/site-packages/pysr/sr.py:567: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /home/lrudl/.pyenv/versions/3.9.10/lib/python3.9/site-packages/pysr/sr.py:567: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(

# %%
sr.save("delete_this")

# %%
saved = t.load("delete_this")

# %%
saved['message_sr_result']
# Out:
# [complexity                                    5
#  loss                                   0.000013
#  score                                  2.692765
#  equation             ((xs1 - xt1) * 0.14108483)
#  sympy_format    0.14108483*xs1 - 0.14108483*xt1
#  Name: 2, dtype: object,
#  complexity                                   5
#  loss                                  0.000076
#  score                                 1.895386
#  equation            ((xs2 - xt2) * -0.1463782)
#  sympy_format    -0.1463782*xs2 + 0.1463782*xt2
#  Name: 2, dtype: object]

# %%
saved['update_sr_result']
# Out:
# [complexity                                 5
#  loss                                0.008939
#  score                                 0.6469
#  equation            ((xt1 + a1) * 0.7498744)
#  sympy_format    0.7498744*a1 + 0.7498744*xt1
#  Name: 2, dtype: object,
#  complexity                            5
#  loss                           0.005355
#  score                          0.837864
#  equation        (a2 - (xt2 * 0.525455))
#  sympy_format          a2 - 0.525455*xt2
#  Name: 2, dtype: object]

# %%
saved['message_variable_order']
# Out:
# [[xt1, xt2, xs1, xs2], [xt1, xt2, xs1, xs2]]

# %%
RecoveredGN.load("delete_this")
# Out:
# RecoveredGN()

# %%
(sim3r, sim3m) = view_run_results("runs/copied/act_inh_simple_bigger_nets")

# %%
find_rules_for_model(sim3m, save_location="runs/copied/act_inh_simple_bigger_nets/sr")

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch as t
from gninvert.graph_compare import model_compare
from gninvert.gns import MultiDiffusionGN

# %%
simgn = MultiDiffusionGN([0.1, 0.1])
prev_model = t.load('models/sim2-prev.pt')
trained_model = t.load('models/sim2-hpmodel1.pt')
trained_model2 = t.load('models/sim2-hpmodel2.pt')

# %%
model_compare(trained_model2, simgn, iterations=10)
# Out:
# Stats for 10 steps for node features:
# Greatest relative difference: 61367.041015625%
# Average relative difference: 1845.9341740608218%
# Smallest relative difference: 100.00004768371582%
# Greatest absolute difference: 0.00038361549377441406
# Average absolute difference: 0.00010409828537376598
# Smallest absolute difference: 2.682209014892578e-07%
# The model being tested finished the run outputting this graph:
# tensor([[0.3974, 0.0364],
#         [0.4171, 0.0364],
#         [0.4210, 0.1048],
#         [0.4168, 0.3117],
#         [0.3485, 0.5102]], grad_fn=<AddmmBackward0>)
# The ground truth model finished the run outputting this graph:
# tensor([[0.3973, 0.0363],
#         [0.4171, 0.0363],
#         [0.4209, 0.1050],
#         [0.4166, 0.3119],
#         [0.3481, 0.5105]])
# (Data(x=[5, 2], edge_index=[2, 10]), Data(x=[5, 2], edge_index=[2, 10]))

# %%
model_compare(trained_model, simgn, iterations=10)
# Out:
# Stats for 10 steps for node features:
# Greatest relative difference: 248329.541015625%
# Average relative difference: 8063.9199912548065%
# Smallest relative difference: 100.00144243240356%
# Greatest absolute difference: 0.0010235309600830078
# Average absolute difference: 0.00037622958479914813
# Smallest absolute difference: 1.1086463928222656e-05%
# The model being tested finished the run outputting this graph:
# tensor([[0.3966, 0.0374],
#         [0.4164, 0.0373],
#         [0.4203, 0.1058],
#         [0.4165, 0.3121],
#         [0.3485, 0.5102]], grad_fn=<AddmmBackward0>)
# The ground truth model finished the run outputting this graph:
# tensor([[0.3973, 0.0363],
#         [0.4171, 0.0363],
#         [0.4209, 0.1050],
#         [0.4166, 0.3119],
#         [0.3481, 0.5105]])
# (Data(x=[5, 2], edge_index=[2, 10]), Data(x=[5, 2], edge_index=[2, 10]))
